# %%
import pandas as pd

# %%
matches = pd.read_csv("league_matches.csv")

# %%
matches.head()
# Out:
#         DATE   TIME            COMP        ROUND  DAY VENUE RESULT  GF  GA  \
# 0  8/13/2021  20:15  Premier League  Matchweek 2  Mon  Away      W   3   1
# 1  8/13/2021  16:30  Premier League  Matchweek 3  Sun  Home      L   2   5
# 2  8/14/2021  17:30  Premier League  Matchweek 4  Sat  Away      D   1   1
# 3  8/14/2021  17:30  Premier League  Matchweek 5  Sat  Home      W   1   0
# 4  8/14/2021  12:30  Premier League  Matchweek 6  Sat  Away      D   1   1
#
#          OPPONENT  ...          CAPTAIN         REFEREE  MATCH REPORT  SH SOT  \
# 0          Wolves  ...      Fernandinho  Andre Marriner  Match Report  13   8
# 1  Leicester City  ...      Fernandinho  Michael Oliver  Match Report  16   5
# 2    Leeds United  ...  Kevin De Bruyne       Mike Dean  Match Report  23   1
# 3         Arsenal  ...  Raheem Sterling  Chris Kavanagh  Match Report  13   5
# 4        West Ham  ...  Raheem Sterling  Anthony Taylor  Match Report  14   7
#
#    DIST FK  PK  SEASON             TEAM
# 0  20.3  2   1    2021  Manchester City
# 1  18.8  1   0    2021  Manchester City
# 2  17.6  1   0    2021  Manchester City
# 3  16.8  0   0    2021  Manchester City
# 4  20.3  1   0    2021  Manchester City
#
# [5 rows x 24 columns]

# %%
matches.shape
# Out:
# (760, 24)

# %%
matches["DATE"] = pd.to_datetime(matches["DATE"])

# %%
matches["TARGET"] = (matches["RESULT"] == "W").astype("int")

# %%
matches
# Out:
#           DATE   TIME            COMP         ROUND  DAY VENUE RESULT  GF  GA  \
# 0   2021-08-13  20:15  Premier League   Matchweek 2  Mon  Away      W   3   1
# 1   2021-08-13  16:30  Premier League   Matchweek 3  Sun  Home      L   2   5
# 2   2021-08-14  17:30  Premier League   Matchweek 4  Sat  Away      D   1   1
# 3   2021-08-14  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 4   2021-08-14  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 755 2022-05-22  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 756 2022-05-22  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 757 2022-05-22  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 758 2022-05-22  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 759 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
#            OPPONENT  ...         REFEREE  MATCH REPORT  SH  SOT  DIST FK PK  \
# 0            Wolves  ...  Andre Marriner  Match Report  13    8  20.3  2  1
# 1    Leicester City  ...  Michael Oliver  Match Report  16    5  18.8  1  0
# 2      Leeds United  ...       Mike Dean  Match Report  23    1  17.6  1  0
# 3           Arsenal  ...  Chris Kavanagh  Match Report  13    5  16.8  0  0
# 4          West Ham  ...  Anthony Taylor  Match Report  14    7  20.3  1  0
# ..              ...  ...             ...           ...  ..  ...   ... .. ..
# 755       Tottenham  ...  Andre Marriner  Match Report   8    1  17.4  0  0
# 756  Crystal Palace  ...    Simon Hooper  Match Report   7    0  11.4  1  0
# 757         Everton  ...   Jonathan Moss  Match Report  10    3  17.0  0  0
# 758   Newcastle Utd  ...    Robert Jones  Match Report  11    1  16.0  1  0
# 759         Burnley  ...    Kevin Friend  Match Report  12    3  17.0  0  0
#
#      SEASON              TEAM  TARGET
# 0      2021   Manchester City       1
# 1      2021   Manchester City       0
# 2      2021   Manchester City       0
# 3      2021   Manchester City       1
# 4      2021   Manchester City       0
# ..      ...               ...     ...
# 755    2021  Sheffield United       0
# 756    2021  Sheffield United       0
# 757    2021  Sheffield United       1
# 758    2021  Sheffield United       0
# 759    2021  Sheffield United       1
#
# [760 rows x 25 columns]

# %%
matches["VENUE_CODE"] = matches["VENUE"].astype("category").cat.codes

# %%
matches["OPP_CODE"] = matches["OPPONENT"].astype("category").cat.codes

# %%
matches["HOUR"] = matches["TIME"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["DAY_CODE"] = matches["DATE"].dt.dayofweek

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#from sklearn import linear_model
#model = linear_model.LogisticRegression()

# %%
model = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["DATE"] < '2022-01-01']
test = matches[matches["DATE"] > '2022-01-01']

# %%
predictors = ["VENUE_CODE", "OPP_CODE", "HOUR", "DAY_CODE"]

# %%
model.fit(train[predictors], train["TARGET"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = model.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test["TARGET"], preds)

# %%
accuracy
# Out:
# 0.5283505154639175

# %%
prediction = pd.DataFrame(dict(actual=test["TARGET"], predicted=preds))

# %%
pd.crosstab(index=prediction["actual"], columns=prediction["predicted"])
# Out:
# predicted    0    1
# actual
# 0          136  149
# 1           34   69

# %%
grouped_matches = matches.groupby("TEAM")

# %%
group = grouped_matches.get_group("Manchester United").sort_values("DATE")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("DATE")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["GF", "GA", "SH", "SOT", "DIST", "FK", "PK"]
new_cols = [f"{c}_rolling" for c in cols]

#rolling_averages(group, cols, new_cols)

# %%
matches_rolling = matches.groupby("TEAM").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["DATE"] < '2022-01-01']
    test = data[data["DATE"] > '2022-01-01']
    rf.fit(train[predictors], train["TARGET"])
    preds = rf.predict(test[predictors])
    prediction = pd.DataFrame(dict(actual=test["TARGET"], predicted=preds), index=test.index)
    error = precision_score(test["TARGET"], preds)
    return prediction, error

# %%
prediction = prediction.merge(matches_rolling[["DATE", "TEAM", "OPPONENT", "RESULT"]], left_index=True, right_index=True)

# %%
prediction[prediction["actual"] == prediction["predicted"]]
# Out:
#      actual  predicted       DATE                     TEAM       OPPONENT  \
# 373       1          1 2021-09-25                Liverpool  Sheffield Utd
# 374       0          0 2021-09-25                Liverpool        Chelsea
# 379       0          0 2021-09-25                Liverpool   Leeds United
# 380       1          1 2021-09-25                Liverpool  Newcastle Utd
# 381       1          1 2021-09-25                Liverpool    Southampton
# ..      ...        ...        ...                      ...            ...
# 686       0          0 2022-02-19  Wolverhampton Wanderers      Tottenham
# 689       0          0 2022-02-19  Wolverhampton Wanderers        Chelsea
# 693       1          1 2022-02-20  Wolverhampton Wanderers  Sheffield Utd
# 696       0          0 2022-02-23  Wolverhampton Wanderers        Everton
# 698       0          0 2022-02-23  Wolverhampton Wanderers      West Brom
#
#     RESULT
# 373      W
# 374      L
# 379      D
# 380      D
# 381      W
# ..     ...
# 686      D
# 689      D
# 693      W
# 696      L
# 698      D
#
# [172 rows x 6 columns]
